# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
from sklearn.preprocessing import normalize
from collections import Counter

# Load data
df = pd.read_excel("domain_data_points.xlsx")
texts = df["data_point"].tolist()
labels = df["domain"].tolist()

# Load model and compute embeddings
model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = model.encode(texts, show_progress_bar=True)
normalized_embeddings = normalize(embeddings, norm="l2")

# Create FAISS index
dimension = normalized_embeddings.shape[1]
index = faiss.IndexFlatIP(dimension)
index.add(normalized_embeddings.astype("float32"))

# Map vector ID to domain
id_to_domain = {i: label for i, label in enumerate(labels)}
# Out:
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]

# %%
# Encode and normalize the query
query = "HIV Aids"
query_embedding = model.encode([query])
normalized_query = normalize(query_embedding, norm="l2")

#Search top-k matches
k = 5
D, I = index.search(normalized_query.astype("float32"), k=k)

# Show all top-k results (may include repeated domains)
print("Top-5 matched data points:")
top_domains = []
for i in range(k):
    idx = I[0][i]
    similarity = D[0][i]
    domain = id_to_domain[idx]
    top_domains.append(domain)
    print(f"{i+1}. Domain: {domain}, Similarity: {similarity:.4f}")

# Determine most frequent domain among top-5
domain_counts = Counter(top_domains)
most_common_domain, count = domain_counts.most_common(1)[0]

print("\nMost frequent domain in top-5:", most_common_domain)
# Out:
# Top-5 matched data points:
# 1. Domain: Healthcare, Similarity: 0.2324
# 2. Domain: Healthcare, Similarity: 0.2315
# 3. Domain: Healthcare, Similarity: 0.2279
# 4. Domain: Government Services, Similarity: 0.2273
# 5. Domain: Healthcare, Similarity: 0.2272
#
# Most frequent domain in top-5: Healthcare

# %%
df = pd.read_csv("Attributes_2019-20.csv", delimiter=";")
terms = df["Description"].dropna().unique()
sampled_terms = list(set([t.strip().lower().replace(",", "") for t in terms]))[:300]
cleaned_terms = [t.strip().replace(",", "").lower() for t in terms]

# %%
df.columns
# Out:
# Index(['Attr_id', 'Chapter_id', 'Chapter_name', 'Table_id', 'Table_name',
#        'Description'],
#       dtype='object')

# %%
cols=list(df['Description'])
tab=list(df['Table_name'])

# %%
for i in range(len(cols)):
    # Encode and normalize the query
    query = cols[i]
    query_embedding = model.encode([query])
    normalized_query = normalize(query_embedding, norm="l2")
    
    #Search top-k matches
    k = 5
    D, I = index.search(normalized_query.astype("float32"), k=k)
    
    # Show all top-k results (may include repeated domains)
    print("Top-5 matched data points:")
    top_domains = []
    for i in range(k):
        idx = I[0][i]
        similarity = D[0][i]
        domain = id_to_domain[idx]
        top_domains.append(domain)
        print(f"{i+1}. Domain: {domain}, Similarity: {similarity:.4f}")
    
    # Determine most frequent domain among top-5
    domain_counts = Counter(top_domains)
    most_common_domain, count = domain_counts.most_common(1)[0]
    
    print(query,"\nMost frequent domain in top-5:", most_common_domain)
    print("----------\n\n")
# Out:
# Top-5 matched data points:
# 1. Domain: Finance & Banking, Similarity: 0.2434
# 2. Domain: Travel & Hospitality, Similarity: 0.2379
# 3. Domain: Travel & Hospitality, Similarity: 0.2158
# 4. Domain: E-commerce & Retail, Similarity: 0.2148
# 5. Domain: Government Services, Similarity: 0.2146
# Taluks
# Most frequent domain in top-5: Travel & Hospitality
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: E-commerce & Retail, Similarity: 0.2351
# 2. Domain: E-commerce & Retail, Similarity: 0.2308
# 3. Domain: E-commerce & Retail, Similarity: 0.2155
# 4. Domain: E-commerce & Retail, Similarity: 0.2046
# 5. Domain: Startups and IT Services, Similarity: 0.2026
# Hoblies
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.2786
# 2. Domain: Startups and IT Services, Similarity: 0.2669
# 3. Domain: Finance & Banking, Similarity: 0.2650
# 4. Domain: Government Services, Similarity: 0.2522
# 5. Domain: Employment & HR Tech, Similarity: 0.2405
# Grama Panchayaths
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Finance & Banking, Similarity: 0.2089
# 2. Domain: Travel & Hospitality, Similarity: 0.2032
# 3. Domain: Government Services, Similarity: 0.2031
# 4. Domain: Government Services, Similarity: 0.1993
# 5. Domain: Government Services, Similarity: 0.1953
# Circles
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.1689
# 2. Domain: Telecommunications, Similarity: 0.1667
# 3. Domain: Startups and IT Services, Similarity: 0.1603
# 4. Domain: Telecommunications, Similarity: 0.1452
# 5. Domain: Telecommunications, Similarity: 0.1419
# Un-Inhabited Inhabited,Villages
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.1689
# 2. Domain: Telecommunications, Similarity: 0.1667
# 3. Domain: Startups and IT Services, Similarity: 0.1603
# 4. Domain: Telecommunications, Similarity: 0.1452
# 5. Domain: Telecommunications, Similarity: 0.1419
# Un-Inhabited Inhabited,Villages
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2481
# 2. Domain: E-commerce & Retail, Similarity: 0.2468
# 3. Domain: Startups and IT Services, Similarity: 0.2170
# 4. Domain: Finance & Banking, Similarity: 0.2161
# 5. Domain: Travel & Hospitality, Similarity: 0.2145
# Total Villages
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Travel & Hospitality, Similarity: 0.3016
# 2. Domain: Startups and IT Services, Similarity: 0.2860
# 3. Domain: Finance & Banking, Similarity: 0.2740
# 4. Domain: Travel & Hospitality, Similarity: 0.2713
# 5. Domain: Travel & Hospitality, Similarity: 0.2632
# Cc,Urban Local Bodies
# Most frequent domain in top-5: Travel & Hospitality
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Finance & Banking, Similarity: 0.2634
# 2. Domain: Finance & Banking, Similarity: 0.2568
# 3. Domain: Finance & Banking, Similarity: 0.2550
# 4. Domain: Finance & Banking, Similarity: 0.2549
# 5. Domain: Healthcare, Similarity: 0.2442
# Cmc,Urban Local Bodies
# Most frequent domain in top-5: Finance & Banking
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2781
# 2. Domain: Travel & Hospitality, Similarity: 0.2709
# 3. Domain: Travel & Hospitality, Similarity: 0.2517
# 4. Domain: Travel & Hospitality, Similarity: 0.2421
# 5. Domain: Startups and IT Services, Similarity: 0.2392
# Tmc,Urban Local Bodies
# Most frequent domain in top-5: Travel & Hospitality
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2464
# 2. Domain: Startups and IT Services, Similarity: 0.2454
# 3. Domain: Startups and IT Services, Similarity: 0.2397
# 4. Domain: Startups and IT Services, Similarity: 0.2378
# 5. Domain: Travel & Hospitality, Similarity: 0.2373
# Tp,Urban Local Bodies
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2409
# 2. Domain: Travel & Hospitality, Similarity: 0.2318
# 3. Domain: Finance & Banking, Similarity: 0.2278
# 4. Domain: Startups and IT Services, Similarity: 0.2222
# 5. Domain: Government Services, Similarity: 0.2200
# NACs,Urban Local Bodies
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2302
# 2. Domain: Startups and IT Services, Similarity: 0.2256
# 3. Domain: Startups and IT Services, Similarity: 0.2166
# 4. Domain: E-commerce & Retail, Similarity: 0.2151
# 5. Domain: Telecommunications, Similarity: 0.2046
# Total,Urban Local Bodies
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Healthcare, Similarity: 0.2401
# 2. Domain: E-commerce & Retail, Similarity: 0.2352
# 3. Domain: Employment & HR Tech, Similarity: 0.2351
# 4. Domain: Startups and IT Services, Similarity: 0.2243
# 5. Domain: Employment & HR Tech, Similarity: 0.2237
# Police Stations
# Most frequent domain in top-5: Employment & HR Tech
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Education, Similarity: 0.2194
# 2. Domain: Finance & Banking, Similarity: 0.2172
# 3. Domain: Education, Similarity: 0.2109
# 4. Domain: Education, Similarity: 0.2070
# 5. Domain: Education, Similarity: 0.2032
# Prisons,Prisons and Prisoners
# Most frequent domain in top-5: Education
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Employment & HR Tech, Similarity: 0.2405
# 2. Domain: Education, Similarity: 0.2278
# 3. Domain: Education, Similarity: 0.2216
# 4. Domain: E-commerce & Retail, Similarity: 0.2170
# 5. Domain: Education, Similarity: 0.2123
# Male,Prisoners,Prisons and Prisoners
# Most frequent domain in top-5: Education
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Education, Similarity: 0.3145
# 2. Domain: Travel & Hospitality, Similarity: 0.2729
# 3. Domain: Education, Similarity: 0.2719
# 4. Domain: Travel & Hospitality, Similarity: 0.2467
# 5. Domain: Education, Similarity: 0.2448
# Female,Prisoners,Prisons and Prisoners
# Most frequent domain in top-5: Education
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.3213
# 2. Domain: Startups and IT Services, Similarity: 0.2728
# 3. Domain: Telecommunications, Similarity: 0.2628
# 4. Domain: Telecommunications, Similarity: 0.2627
# 5. Domain: Startups and IT Services, Similarity: 0.2577
# Fire Brigade Stations
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2935
# 2. Domain: Startups and IT Services, Similarity: 0.2905
# 3. Domain: Startups and IT Services, Similarity: 0.2899
# 4. Domain: Startups and IT Services, Similarity: 0.2896
# 5. Domain: Startups and IT Services, Similarity: 0.2588
# Working Fire Brigade Water Tankers
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.4576
# 2. Domain: Telecommunications, Similarity: 0.4523
# 3. Domain: Telecommunications, Similarity: 0.4495
# 4. Domain: Telecommunications, Similarity: 0.4447
# 5. Domain: Telecommunications, Similarity: 0.4395
# Emergency fire calls received
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Finance & Banking, Similarity: 0.3055
# 2. Domain: Startups and IT Services, Similarity: 0.2848
# 3. Domain: Finance & Banking, Similarity: 0.2754
# 4. Domain: Finance & Banking, Similarity: 0.2718
# 5. Domain: Government Services, Similarity: 0.2614
# Value of the property protected during 2019-20 Rs.in Lakhs
# Most frequent domain in top-5: Finance & Banking
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.4262
# 2. Domain: E-commerce & Retail, Similarity: 0.3981
# 3. Domain: Government Services, Similarity: 0.3925
# 4. Domain: Government Services, Similarity: 0.3676
# 5. Domain: Government Services, Similarity: 0.3641
# Urban,Ration shops
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.3962
# 2. Domain: E-commerce & Retail, Similarity: 0.3853
# 3. Domain: E-commerce & Retail, Similarity: 0.3722
# 4. Domain: E-commerce & Retail, Similarity: 0.3630
# 5. Domain: Government Services, Similarity: 0.3557
# Rural,Ration shops
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.4514
# 2. Domain: Government Services, Similarity: 0.4455
# 3. Domain: E-commerce & Retail, Similarity: 0.4311
# 4. Domain: E-commerce & Retail, Similarity: 0.4215
# 5. Domain: Government Services, Similarity: 0.4212
# Total,Ration shops
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.5672
# 2. Domain: Government Services, Similarity: 0.5637
# 3. Domain: Government Services, Similarity: 0.5586
# 4. Domain: Government Services, Similarity: 0.5451
# 5. Domain: Government Services, Similarity: 0.5438
# Urban,Anthyodaya,Ration card holders
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.5500
# 2. Domain: Government Services, Similarity: 0.5321
# 3. Domain: Government Services, Similarity: 0.5123
# 4. Domain: Government Services, Similarity: 0.5049
# 5. Domain: Government Services, Similarity: 0.5028
# Rural,Anthyodaya,Ration card holders
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.5765
# 2. Domain: Government Services, Similarity: 0.5762
# 3. Domain: Government Services, Similarity: 0.5650
# 4. Domain: Government Services, Similarity: 0.5484
# 5. Domain: Government Services, Similarity: 0.5429
# Total,Anthyodaya,Ration card holders
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2491
# 2. Domain: Startups and IT Services, Similarity: 0.2283
# 3. Domain: Startups and IT Services, Similarity: 0.2253
# 4. Domain: Startups and IT Services, Similarity: 0.2238
# 5. Domain: E-commerce & Retail, Similarity: 0.2182
# Urban,Priority
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2668
# 2. Domain: Startups and IT Services, Similarity: 0.2360
# 3. Domain: Startups and IT Services, Similarity: 0.2353
# 4. Domain: Startups and IT Services, Similarity: 0.2296
# 5. Domain: Startups and IT Services, Similarity: 0.2287
# Rural,Priority
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: E-commerce & Retail, Similarity: 0.3055
# 2. Domain: E-commerce & Retail, Similarity: 0.2914
# 3. Domain: E-commerce & Retail, Similarity: 0.2559
# 4. Domain: E-commerce & Retail, Similarity: 0.2521
# 5. Domain: Startups and IT Services, Similarity: 0.2477
# Total,Priority
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2513
# 2. Domain: Startups and IT Services, Similarity: 0.2270
# 3. Domain: Startups and IT Services, Similarity: 0.2252
# 4. Domain: Startups and IT Services, Similarity: 0.2235
# 5. Domain: Startups and IT Services, Similarity: 0.2177
# Urban,Non Priority
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2658
# 2. Domain: Startups and IT Services, Similarity: 0.2377
# 3. Domain: Startups and IT Services, Similarity: 0.2352
# 4. Domain: Startups and IT Services, Similarity: 0.2351
# 5. Domain: Government Services, Similarity: 0.2240
# Rural,Non Priority
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: E-commerce & Retail, Similarity: 0.2924
# 2. Domain: E-commerce & Retail, Similarity: 0.2891
# 3. Domain: E-commerce & Retail, Similarity: 0.2537
# 4. Domain: E-commerce & Retail, Similarity: 0.2481
# 5. Domain: E-commerce & Retail, Similarity: 0.2468
# Total,Non Priority
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.4480
# 2. Domain: Government Services, Similarity: 0.4332
# 3. Domain: Government Services, Similarity: 0.4235
# 4. Domain: Government Services, Similarity: 0.4127
# 5. Domain: Government Services, Similarity: 0.4116
# Urban,Total Card Hold
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.4379
# 2. Domain: Government Services, Similarity: 0.4216
# 3. Domain: Government Services, Similarity: 0.4198
# 4. Domain: Government Services, Similarity: 0.4117
# 5. Domain: Government Services, Similarity: 0.4051
# Rural,Total Card Hold
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.4109
# 2. Domain: Government Services, Similarity: 0.3967
# 3. Domain: Government Services, Similarity: 0.3940
# 4. Domain: E-commerce & Retail, Similarity: 0.3915
# 5. Domain: Government Services, Similarity: 0.3865
# Total,Total Card Hold
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2640
# 2. Domain: Startups and IT Services, Similarity: 0.2631
# 3. Domain: Travel & Hospitality, Similarity: 0.2449
# 4. Domain: Startups and IT Services, Similarity: 0.2363
# 5. Domain: Startups and IT Services, Similarity: 0.2345
# Urban,with cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.3053
# 2. Domain: E-commerce & Retail, Similarity: 0.2961
# 3. Domain: Startups and IT Services, Similarity: 0.2661
# 4. Domain: Startups and IT Services, Similarity: 0.2632
# 5. Domain: Finance & Banking, Similarity: 0.2569
# Rural,with cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: E-commerce & Retail, Similarity: 0.3108
# 2. Domain: E-commerce & Retail, Similarity: 0.2956
# 3. Domain: E-commerce & Retail, Similarity: 0.2792
# 4. Domain: E-commerce & Retail, Similarity: 0.2664
# 5. Domain: Finance & Banking, Similarity: 0.2598
# Total,with cylinder
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2544
# 2. Domain: E-commerce & Retail, Similarity: 0.2518
# 3. Domain: Government Services, Similarity: 0.2470
# 4. Domain: Government Services, Similarity: 0.2465
# 5. Domain: Startups and IT Services, Similarity: 0.2377
# % to State total,with cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2390
# 2. Domain: Travel & Hospitality, Similarity: 0.2202
# 3. Domain: Startups and IT Services, Similarity: 0.2183
# 4. Domain: Travel & Hospitality, Similarity: 0.2061
# 5. Domain: Startups and IT Services, Similarity: 0.1992
# Urban,without cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2602
# 2. Domain: E-commerce & Retail, Similarity: 0.2431
# 3. Domain: Startups and IT Services, Similarity: 0.2226
# 4. Domain: Startups and IT Services, Similarity: 0.2202
# 5. Domain: Startups and IT Services, Similarity: 0.2194
# Rural,without cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: E-commerce & Retail, Similarity: 0.3035
# 2. Domain: E-commerce & Retail, Similarity: 0.2774
# 3. Domain: E-commerce & Retail, Similarity: 0.2703
# 4. Domain: E-commerce & Retail, Similarity: 0.2582
# 5. Domain: E-commerce & Retail, Similarity: 0.2560
# Total,without cylinder
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.2528
# 2. Domain: E-commerce & Retail, Similarity: 0.2501
# 3. Domain: Government Services, Similarity: 0.2466
# 4. Domain: Startups and IT Services, Similarity: 0.2381
# 5. Domain: Government Services, Similarity: 0.2249
# % to State total,without cylinder
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2640
# 2. Domain: Startups and IT Services, Similarity: 0.2631
# 3. Domain: Travel & Hospitality, Similarity: 0.2449
# 4. Domain: Startups and IT Services, Similarity: 0.2363
# 5. Domain: Startups and IT Services, Similarity: 0.2345
# Urban,with cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.3053
# 2. Domain: E-commerce & Retail, Similarity: 0.2961
# 3. Domain: Startups and IT Services, Similarity: 0.2661
# 4. Domain: Startups and IT Services, Similarity: 0.2632
# 5. Domain: Finance & Banking, Similarity: 0.2569
# Rural,with cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: E-commerce & Retail, Similarity: 0.3108
# 2. Domain: E-commerce & Retail, Similarity: 0.2956
# 3. Domain: E-commerce & Retail, Similarity: 0.2792
# 4. Domain: E-commerce & Retail, Similarity: 0.2664
# 5. Domain: Finance & Banking, Similarity: 0.2598
# Total,with cylinder
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2544
# 2. Domain: E-commerce & Retail, Similarity: 0.2518
# 3. Domain: Government Services, Similarity: 0.2470
# 4. Domain: Government Services, Similarity: 0.2465
# 5. Domain: Startups and IT Services, Similarity: 0.2377
# % to State total,with cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2390
# 2. Domain: Travel & Hospitality, Similarity: 0.2202
# 3. Domain: Startups and IT Services, Similarity: 0.2183
# 4. Domain: Travel & Hospitality, Similarity: 0.2061
# 5. Domain: Startups and IT Services, Similarity: 0.1992
# Urban,without cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2602
# 2. Domain: E-commerce & Retail, Similarity: 0.2431
# 3. Domain: Startups and IT Services, Similarity: 0.2226
# 4. Domain: Startups and IT Services, Similarity: 0.2202
# 5. Domain: Startups and IT Services, Similarity: 0.2194
# Rural,without cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: E-commerce & Retail, Similarity: 0.3035
# 2. Domain: E-commerce & Retail, Similarity: 0.2774
# 3. Domain: E-commerce & Retail, Similarity: 0.2703
# 4. Domain: E-commerce & Retail, Similarity: 0.2582
# 5. Domain: E-commerce & Retail, Similarity: 0.2560
# Total,without cylinder
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.2528
# 2. Domain: E-commerce & Retail, Similarity: 0.2501
# 3. Domain: Government Services, Similarity: 0.2466
# 4. Domain: Startups and IT Services, Similarity: 0.2381
# 5. Domain: Government Services, Similarity: 0.2249
# % to State total,without cylinder
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2640
# 2. Domain: Startups and IT Services, Similarity: 0.2631
# 3. Domain: Travel & Hospitality, Similarity: 0.2449
# 4. Domain: Startups and IT Services, Similarity: 0.2363
# 5. Domain: Startups and IT Services, Similarity: 0.2345
# Urban,with cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.3053
# 2. Domain: E-commerce & Retail, Similarity: 0.2961
# 3. Domain: Startups and IT Services, Similarity: 0.2661
# 4. Domain: Startups and IT Services, Similarity: 0.2632
# 5. Domain: Finance & Banking, Similarity: 0.2569
# Rural,with cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: E-commerce & Retail, Similarity: 0.3108
# 2. Domain: E-commerce & Retail, Similarity: 0.2956
# 3. Domain: E-commerce & Retail, Similarity: 0.2792
# 4. Domain: E-commerce & Retail, Similarity: 0.2664
# 5. Domain: Finance & Banking, Similarity: 0.2598
# Total,with cylinder
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2544
# 2. Domain: E-commerce & Retail, Similarity: 0.2518
# 3. Domain: Government Services, Similarity: 0.2470
# 4. Domain: Government Services, Similarity: 0.2465
# 5. Domain: Startups and IT Services, Similarity: 0.2377
# % to State total,with cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2390
# 2. Domain: Travel & Hospitality, Similarity: 0.2202
# 3. Domain: Startups and IT Services, Similarity: 0.2183
# 4. Domain: Travel & Hospitality, Similarity: 0.2061
# 5. Domain: Startups and IT Services, Similarity: 0.1992
# Urban,without cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2602
# 2. Domain: E-commerce & Retail, Similarity: 0.2431
# 3. Domain: Startups and IT Services, Similarity: 0.2226
# 4. Domain: Startups and IT Services, Similarity: 0.2202
# 5. Domain: Startups and IT Services, Similarity: 0.2194
# Rural,without cylinder
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: E-commerce & Retail, Similarity: 0.3035
# 2. Domain: E-commerce & Retail, Similarity: 0.2774
# 3. Domain: E-commerce & Retail, Similarity: 0.2703
# 4. Domain: E-commerce & Retail, Similarity: 0.2582
# 5. Domain: E-commerce & Retail, Similarity: 0.2560
# Total,without cylinder
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.2451
# 2. Domain: Government Services, Similarity: 0.2381
# 3. Domain: Startups and IT Services, Similarity: 0.2305
# 4. Domain: E-commerce & Retail, Similarity: 0.2302
# 5. Domain: Government Services, Similarity: 0.2242
# % % to State total,without cylinder
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: E-commerce & Retail, Similarity: 0.3075
# 2. Domain: E-commerce & Retail, Similarity: 0.3013
# 3. Domain: E-commerce & Retail, Similarity: 0.2922
# 4. Domain: Telecommunications, Similarity: 0.2791
# 5. Domain: Startups and IT Services, Similarity: 0.2741
# Gross District Domestic Product Gddp Rs. in Lakhs,2017 At Current Prices 2017-18
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: E-commerce & Retail, Similarity: 0.3807
# 2. Domain: E-commerce & Retail, Similarity: 0.3294
# 3. Domain: E-commerce & Retail, Similarity: 0.3150
# 4. Domain: E-commerce & Retail, Similarity: 0.3138
# 5. Domain: E-commerce & Retail, Similarity: 0.2987
# Net District Domestic Product Nddp Rs. in Lakhs,2017 At Current Prices 2017-18
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: E-commerce & Retail, Similarity: 0.3122
# 2. Domain: E-commerce & Retail, Similarity: 0.2925
# 3. Domain: Telecommunications, Similarity: 0.2900
# 4. Domain: Startups and IT Services, Similarity: 0.2834
# 5. Domain: Telecommunications, Similarity: 0.2760
# Gross District Domestic Product Gddp Rs. in Lakhs,At Constant Prices 2017-18
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: E-commerce & Retail, Similarity: 0.3790
# 2. Domain: E-commerce & Retail, Similarity: 0.3324
# 3. Domain: E-commerce & Retail, Similarity: 0.3066
# 4. Domain: E-commerce & Retail, Similarity: 0.3034
# 5. Domain: E-commerce & Retail, Similarity: 0.2897
# Net District Domestic Product Nddp Rs. in Lakhs,At Constant Prices 2017-18
# Most frequent domain in top-5: E-commerce & Retail
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.3516
# 2. Domain: Telecommunications, Similarity: 0.3487
# 3. Domain: Telecommunications, Similarity: 0.3379
# 4. Domain: Telecommunications, Similarity: 0.3285
# 5. Domain: Telecommunications, Similarity: 0.3285
# At Current Prices 2017-18,Per capita Income In Rs.
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.3580
# 2. Domain: Telecommunications, Similarity: 0.3522
# 3. Domain: Telecommunications, Similarity: 0.3367
# 4. Domain: Telecommunications, Similarity: 0.3336
# 5. Domain: Telecommunications, Similarity: 0.3280
# At constant Prices 2017-18,Per capita Income In Rs.
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Travel & Hospitality, Similarity: 0.2269
# 2. Domain: Travel & Hospitality, Similarity: 0.2211
# 3. Domain: Travel & Hospitality, Similarity: 0.2211
# 4. Domain: E-commerce & Retail, Similarity: 0.2200
# 5. Domain: E-commerce & Retail, Similarity: 0.2194
# Rank
# Most frequent domain in top-5: Travel & Hospitality
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.2034
# 2. Domain: Telecommunications, Similarity: 0.1785
# 3. Domain: Telecommunications, Similarity: 0.1631
# 4. Domain: Telecommunications, Similarity: 0.1584
# 5. Domain: Startups and IT Services, Similarity: 0.1577
# Geograpical Area Sq.Kms
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.2948
# 2. Domain: Telecommunications, Similarity: 0.2863
# 3. Domain: Telecommunications, Similarity: 0.2852
# 4. Domain: Telecommunications, Similarity: 0.2842
# 5. Domain: Telecommunications, Similarity: 0.2690
# Population Density
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Finance & Banking, Similarity: 0.3060
# 2. Domain: Travel & Hospitality, Similarity: 0.2853
# 3. Domain: Finance & Banking, Similarity: 0.2703
# 4. Domain: Travel & Hospitality, Similarity: 0.2694
# 5. Domain: Finance & Banking, Similarity: 0.2650
# Rual,Households
# Most frequent domain in top-5: Finance & Banking
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2573
# 2. Domain: Telecommunications, Similarity: 0.2564
# 3. Domain: Government Services, Similarity: 0.2505
# 4. Domain: Telecommunications, Similarity: 0.2502
# 5. Domain: Government Services, Similarity: 0.2500
# Urban,Households
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.2517
# 2. Domain: Telecommunications, Similarity: 0.2384
# 3. Domain: Telecommunications, Similarity: 0.2364
# 4. Domain: Telecommunications, Similarity: 0.2324
# 5. Domain: Telecommunications, Similarity: 0.2305
# Total,Households
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Social Media & Entertainment, Similarity: 0.3246
# 2. Domain: Social Media & Entertainment, Similarity: 0.3135
# 3. Domain: Social Media & Entertainment, Similarity: 0.3065
# 4. Domain: Social Media & Entertainment, Similarity: 0.3031
# 5. Domain: Social Media & Entertainment, Similarity: 0.3017
# % Share to Total Households
# Most frequent domain in top-5: Social Media & Entertainment
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Travel & Hospitality, Similarity: 0.2269
# 2. Domain: Travel & Hospitality, Similarity: 0.2211
# 3. Domain: Travel & Hospitality, Similarity: 0.2211
# 4. Domain: E-commerce & Retail, Similarity: 0.2200
# 5. Domain: E-commerce & Retail, Similarity: 0.2194
# Rank
# Most frequent domain in top-5: Travel & Hospitality
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.2868
# 2. Domain: Telecommunications, Similarity: 0.2811
# 3. Domain: Telecommunications, Similarity: 0.2796
# 4. Domain: Telecommunications, Similarity: 0.2745
# 5. Domain: Telecommunications, Similarity: 0.2712
# Projected households in 2020
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.3088
# 2. Domain: Telecommunications, Similarity: 0.2993
# 3. Domain: Telecommunications, Similarity: 0.2875
# 4. Domain: Telecommunications, Similarity: 0.2634
# 5. Domain: Telecommunications, Similarity: 0.2602
# Total,Population
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.2570
# 2. Domain: Telecommunications, Similarity: 0.2130
# 3. Domain: Telecommunications, Similarity: 0.2024
# 4. Domain: Telecommunications, Similarity: 0.1994
# 5. Domain: Telecommunications, Similarity: 0.1924
# Male,Population
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.2668
# 2. Domain: Government Services, Similarity: 0.2266
# 3. Domain: Education, Similarity: 0.2224
# 4. Domain: Government Services, Similarity: 0.2195
# 5. Domain: Finance & Banking, Similarity: 0.2183
# Female,Population
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Social Media & Entertainment, Similarity: 0.3023
# 2. Domain: Social Media & Entertainment, Similarity: 0.2967
# 3. Domain: Social Media & Entertainment, Similarity: 0.2809
# 4. Domain: Social Media & Entertainment, Similarity: 0.2773
# 5. Domain: Social Media & Entertainment, Similarity: 0.2760
# % Share to Total Population
# Most frequent domain in top-5: Social Media & Entertainment
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Travel & Hospitality, Similarity: 0.2269
# 2. Domain: Travel & Hospitality, Similarity: 0.2211
# 3. Domain: Travel & Hospitality, Similarity: 0.2211
# 4. Domain: E-commerce & Retail, Similarity: 0.2200
# 5. Domain: E-commerce & Retail, Similarity: 0.2194
# Rank
# Most frequent domain in top-5: Travel & Hospitality
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.3088
# 2. Domain: Telecommunications, Similarity: 0.2993
# 3. Domain: Telecommunications, Similarity: 0.2875
# 4. Domain: Telecommunications, Similarity: 0.2634
# 5. Domain: Telecommunications, Similarity: 0.2602
# Total,Population
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.2570
# 2. Domain: Telecommunications, Similarity: 0.2130
# 3. Domain: Telecommunications, Similarity: 0.2024
# 4. Domain: Telecommunications, Similarity: 0.1994
# 5. Domain: Telecommunications, Similarity: 0.1924
# Male,Population
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.2668
# 2. Domain: Government Services, Similarity: 0.2266
# 3. Domain: Education, Similarity: 0.2224
# 4. Domain: Government Services, Similarity: 0.2195
# 5. Domain: Finance & Banking, Similarity: 0.2183
# Female,Population
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Social Media & Entertainment, Similarity: 0.3023
# 2. Domain: Social Media & Entertainment, Similarity: 0.2967
# 3. Domain: Social Media & Entertainment, Similarity: 0.2809
# 4. Domain: Social Media & Entertainment, Similarity: 0.2773
# 5. Domain: Social Media & Entertainment, Similarity: 0.2760
# % Share to Total Population
# Most frequent domain in top-5: Social Media & Entertainment
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Travel & Hospitality, Similarity: 0.2269
# 2. Domain: Travel & Hospitality, Similarity: 0.2211
# 3. Domain: Travel & Hospitality, Similarity: 0.2211
# 4. Domain: E-commerce & Retail, Similarity: 0.2200
# 5. Domain: E-commerce & Retail, Similarity: 0.2194
# Rank
# Most frequent domain in top-5: Travel & Hospitality
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Startups and IT Services, Similarity: 0.2398
# 2. Domain: Startups and IT Services, Similarity: 0.2358
# 3. Domain: Startups and IT Services, Similarity: 0.2355
# 4. Domain: Government Services, Similarity: 0.2301
# 5. Domain: Finance & Banking, Similarity: 0.2279
# Male,Rural,Population 2011
# Most frequent domain in top-5: Startups and IT Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.2963
# 2. Domain: Government Services, Similarity: 0.2866
# 3. Domain: Finance & Banking, Similarity: 0.2823
# 4. Domain: Finance & Banking, Similarity: 0.2650
# 5. Domain: Government Services, Similarity: 0.2557
# Female,Rural,Population 2011
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Telecommunications, Similarity: 0.2598
# 2. Domain: Telecommunications, Similarity: 0.2518
# 3. Domain: Telecommunications, Similarity: 0.2305
# 4. Domain: Telecommunications, Similarity: 0.2303
# 5. Domain: Telecommunications, Similarity: 0.2229
# Total,Rural,Population 2011
# Most frequent domain in top-5: Telecommunications
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.2264
# 2. Domain: Government Services, Similarity: 0.2242
# 3. Domain: Startups and IT Services, Similarity: 0.2169
# 4. Domain: Startups and IT Services, Similarity: 0.2109
# 5. Domain: Government Services, Similarity: 0.2048
# Male,Urban,Population 2011
# Most frequent domain in top-5: Government Services
# ----------
#
#
# Top-5 matched data points:
# 1. Domain: Government Services, Similarity: 0.2970
# 2. Domain: Government Services, Similarity: 0.2757
# 3. Domain: Government Services, Similarity: 0.2678
# 4. Domain: Government Services, Similarity: 0.2616
# 5. Domain: Government Services, Similarity: 0.2535
# Female,Urban,Population 2011
# Most frequent domain in top-5: Government Services
# ----------
